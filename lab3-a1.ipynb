# %% [markdown]
# <a href="https://colab.research.google.com/github/deva-kumari/devakumari_cse22237/blob/main/lab3-a1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Load the dataset
file_path = '/mnt/cc_embed_data.csv'
dataset = pd.read_csv(file_path)

# Group by 'Final_Marks' to calculate class centroids and spreads
grouped = dataset.groupby('Final_Marks')

# Calculate the centroids (means) and spreads (standard deviations) for each class
centroids = grouped.mean()
spreads = grouped.std()

# Function to calculate the Euclidean distance between centroids of two classes
def calculate_distance(class1, class2, centroids):
    centroid1 = centroids.loc[class1].values
    centroid2 = centroids.loc[class2].values
    distance = np.linalg.norm(centroid1 - centroid2)
    return distance

# Example: Calculate the distance between centroids of class 10 and class 8
distance_10_8 = calculate_distance(10, 8, centroids)

# Print centroids, spreads, and the distance between centroids of class 10 and class 8
print("Centroids:\n", centroids)
print("\nSpreads:\n", spreads)
print(f"\nDistance between centroids of class 10 and class 8: {distance_10_8}")
# Out:
# Centroids:
#               cc_embedding_0  cc_embedding_1  cc_embedding_2  cc_embedding_3  \
# Final_Marks
# 0                 -2.098783       -0.438802        0.313613        0.091644
# 1                 -1.282555       -0.320113        0.400256       -0.115213
# 2                 -1.136634       -0.159596        0.647009       -0.110770
# 3                 -0.777190        0.326369        0.740171       -0.213168
# 4                 -0.684537        0.322436        0.754378        0.018292
# 5                 -1.142291        0.500370        0.984307        0.149214
# 6                 -1.050220        0.151855        0.554208        0.315028
# 7                 -1.042854        0.353295        0.803771        0.297921
# 8                 -1.145387        0.089097        0.627286        0.106001
# 9                 -1.117384        0.225595        0.366313        0.141905
# 10                -1.095213       -0.033141        0.601416        0.220896
#
# ...
