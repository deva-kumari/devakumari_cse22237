# %% [markdown]
# <a href="https://colab.research.google.com/github/deva-kumari/devakumari_cse22237/blob/main/lab3-a2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the dataset
file_path = '/mnt/cc_embed_data.csv'
dataset = pd.read_csv(file_path)

# Select the feature 'cc_embedding_0'
feature = dataset['cc_embedding_0']

# Calculate the histogram data
hist_data, bin_edges = np.histogram(feature, bins=10)

# Plot the histogram
plt.hist(feature, bins=10, edgecolor='black')
plt.title('Histogram of cc_embedding_0')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# Calculate the mean and variance of the feature
mean_value = np.mean(feature)
variance_value = np.var(feature)

print(f"Mean: {mean_value}")
print(f"Variance: {variance_value}")
# Out:
# Mean: -1.0052035570884355
# Variance: 1.0764497194195817
